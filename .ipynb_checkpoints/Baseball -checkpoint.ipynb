# %%
install.packages("Lahman")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("data.table")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library("Lahman")

# %%
library("data.table")

# %%
teams = as.data.table(Teams)

# %%
## model1 = lm(data$readingScore ~ data$grade + data$male + data$raceeth + data$preschool + data$expectBachelors 
#            + data$motherHS + data$motherBachelors + data$motherWork + data$fatherHS + data$fatherBachelors + data$fatherWork
#            + data$selfBornUS +data$motherBornUS + data$fatherBornUS + data$englishAtHome + data$computerForSchoolwork
#            + data$read30MinsADay + data$minutesPerWeekEnglish + data$studentsInEnglish + data$schoolHasLibrary
#            + data$publicSchool + data$urban + data$schoolSize,data = data)
# summary(model1)

# %%
teams = teams[, .(yearID, 
                  lgID = as.character(lgID), 
                  teamID = as.character(teamID), 
                  franchID = as.character(franchID),
                  Rank, G, W, L, R, ERA, SO, 
                  WinPercent = W/(W+L))]

# %%
salaries = as.data.table(Salaries)

# %%
salaries = salaries[, c("lgID", "teamID", "salary1M") := 
                      list(as.character(lgID), as.character(teamID), salary / 1e6L)]

# %%
payroll = salaries[, .(payroll = sum(salary1M)), by=.(teamID, yearID)]

# %%
teamPayroll = merge(teams, payroll, by=c("teamID","yearID")) #merge teams and payroll data sets together

# %%
head(teamPayroll)
# Out:
#   teamID yearID lgID franchID Rank G   W  L  R   ERA  SO   WinPercent payroll
# 1 ANA    1997   AL   ANA      2    162 84 78 829 4.52  953 0.5185185  31.13547
# 2 ANA    1998   AL   ANA      2    162 85 77 787 4.49 1028 0.5246914  41.28100
# 3 ANA    1999   AL   ANA      4    162 70 92 711 4.79 1022 0.4320988  55.38817
# 4 ANA    2000   AL   ANA      3    162 82 80 864 5.00 1024 0.5061728  51.46417
# 5 ANA    2001   AL   ANA      3    162 75 87 691 4.20 1001 0.4629630  47.53517
# 6 ANA    2002   AL   ANA      2    162 99 63 851 3.69  805 0.6111111  61.72167

# %%
head(teamPayroll) #all payroll data
# Out:
#   teamID yearID lgID franchID Rank G   W  L  R   ERA  SO   WinPercent payroll
# 1 ANA    1997   AL   ANA      2    162 84 78 829 4.52  953 0.5185185  31.13547
# 2 ANA    1998   AL   ANA      2    162 85 77 787 4.49 1028 0.5246914  41.28100
# 3 ANA    1999   AL   ANA      4    162 70 92 711 4.79 1022 0.4320988  55.38817
# 4 ANA    2000   AL   ANA      3    162 82 80 864 5.00 1024 0.5061728  51.46417
# 5 ANA    2001   AL   ANA      3    162 75 87 691 4.20 1001 0.4629630  47.53517
# 6 ANA    2002   AL   ANA      2    162 99 63 851 3.69  805 0.6111111  61.72167

# %%
teamPayrollP <- teamPayroll[yearID >= "2000"]

# %%
head(teamPayrollP)
# Out:
#   teamID yearID lgID franchID Rank G   W  L  R   ERA  SO   WinPercent payroll
# 1 ANA    2000   AL   ANA      3    162 82 80 864 5.00 1024 0.5061728   51.46417
# 2 ANA    2001   AL   ANA      3    162 75 87 691 4.20 1001 0.4629630   47.53517
# 3 ANA    2002   AL   ANA      2    162 99 63 851 3.69  805 0.6111111   61.72167
# 4 ANA    2003   AL   ANA      3    162 77 85 736 4.28  838 0.4753086   79.03167
# 5 ANA    2004   AL   ANA      1    162 92 70 836 4.28  942 0.5679012  100.53467
# 6 ARI    2000   NL   ARI      3    162 85 77 792 4.35  975 0.5246914   81.02783

# %%
install.packages("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library("ggplot2") #load ggplot2 package

# %%
ggplot(teamPayrollP, #linear regression graph of payroll and winpercentage
       aes(x= payroll, y = WinPercent)) +geom_point() + stat_smooth(method = "lm", col = "red")
# Out:
# plot without title

# %%
require(ggplot2)
#> Loading required package: ggplot2

# %%
ggplot(data = teamPayrollP, mapping = aes(x = payroll, y = WinPercent)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE)
# Out:
# plot without title

# %%
summary(lm(formula = WinPercent ~ payroll, data = teamPayrollP))
# Out:
# Call:
# lm(formula = WinPercent ~ payroll, data = teamPayrollP)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.212122 -0.050569  0.002469  0.051957  0.223136
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.480e-01  6.979e-03  64.191  < 2e-16 ***
# payroll     6.011e-04  7.327e-05   8.204 1.93e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06599 on 508 degrees of freedom
# Multiple R-squared:  0.117,	Adjusted R-squared:  0.1152
# F-statistic:  67.3 on 1 and 508 DF,  p-value: 1.925e-15

# %%
g2<-ggplot(teamPayrollP,aes(WinPercent,payroll))+geom_point()+geom_smooth(method = "lm")

# %%
library(ggplot2)
# Basic density

# %%
p<- ggplot(teamPayrollP, aes(x=payroll)) + 
  geom_density()
# Add mean line

# %%
ggplot(teamPayrollP, aes(x=payroll)) + geom_density()
# Out:
# plot without title

# %%
ggplot(teamPayrollP, aes(x = payroll)) +
  geom_histogram(aes(y = ..density..), # the histogram will display "density" on its y-axis
                 binwidth = .5) +
  geom_density(alpha = .2, fill="#FF6655") #overlay with a transparent (alpha value) density plot
# Out:
# plot without title

# %%
install.packages("ggExtra")
# Out:
# also installing the dependencies ‘yaml’, ‘htmlwidgets’, ‘httpuv’, ‘mime’, ‘xtable’, ‘sourcetools’, ‘later’, ‘promises’, ‘colourpicker’, ‘miniUI’, ‘shiny’, ‘shinyjs’
#
# Warning message in install.packages("ggExtra"):
# “installation of package ‘httpuv’ had non-zero exit status”Warning message in install.packages("ggExtra"):
# “installation of package ‘shiny’ had non-zero exit status”Warning message in install.packages("ggExtra"):
# “installation of package ‘miniUI’ had non-zero exit status”Warning message in install.packages("ggExtra"):
# “installation of package ‘shinyjs’ had non-zero exit status”Warning message in install.packages("ggExtra"):
# “installation of package ‘colourpicker’ had non-zero exit status”Warning message in install.packages("ggExtra"):
# “installation of package ‘ggExtra’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library("ggExtra")
# Out:
# Error in library("ggExtra"): there is no package called ‘ggExtra’
# Traceback:
#
# 1. library("ggExtra")
# 2. stop(txt, domain = NA)

# %%
set.seed(30)
p <- ggplot(teamPayrollP, aes(x=payroll, y=WinPercent)) + geom_point()

# %%
head(teamPayrollP)
# Out:
#   teamID yearID lgID franchID Rank G   W  L  R   ERA  SO   WinPercent payroll
# 1 ANA    2000   AL   ANA      3    162 82 80 864 5.00 1024 0.5061728   51.46417
# 2 ANA    2001   AL   ANA      3    162 75 87 691 4.20 1001 0.4629630   47.53517
# 3 ANA    2002   AL   ANA      2    162 99 63 851 3.69  805 0.6111111   61.72167
# 4 ANA    2003   AL   ANA      3    162 77 85 736 4.28  838 0.4753086   79.03167
# 5 ANA    2004   AL   ANA      1    162 92 70 836 4.28  942 0.5679012  100.53467
# 6 ARI    2000   NL   ARI      3    162 85 77 792 4.35  975 0.5246914   81.02783

# %%
ggplot(teamPayrollP, aes(payroll)) + geom_histogram(binwidth=10)
# Out:
# plot without title

# %%
ggplot(teamPayrollP, aes(payroll)) + geom_freqpoly(binwidth=10)
# Out:
# plot without title

# %%
moneyball <- read.csv("baseball.csv")

# %%
dataAfter2000 <- subset(moneyball, Year >= 2000)

# %%
m <- ggplot(dataAfter2000, aes(x = W,
                               y = Team,
                               color = factor(Playoffs))) +
geom_point() + scale_color_manual(values = c("#000000", "#FF2D00"), name = "Made Playoffs")

m + geom_vline(aes(xintercept = 95), color = "black", linetype = "dashed", size=1) + xlab("Wins")
# Out:
# plot without title

# %%
dataAfter2000$RD <- dataAfter2000$RS - dataAfter2000$RA

ggplot(dataAfter2000, aes(x = RD,
                            y = W,
                            color = factor(Playoffs))) +
     geom_point() + scale_color_manual(values = c("#000000", "#FF2D00"), name = "Made Playoffs")
# Out:
# plot without title

# %%
winsReg <- lm(W ~ RD, data = dataAfter2000)
winsReg
# Out:
# Call:
# lm(formula = W ~ RD, data = dataAfter2000)
#
# Coefficients:
# (Intercept)           RD
#     80.9615       0.1011

# %%
ggplot(dataAfter2000, aes(x = RD,
                            y = W,
                            color = factor(Playoffs))) +
     geom_point() + scale_color_manual(values = c("#000000", "#FF2D00"), name = "Made Playoffs") +
     geom_vline(aes(xintercept = 133), color = "black", linetype = "dashed", size=1)
# Out:
# plot without title

# %%
head(Pitching)
# Out:
#   playerID  yearID stint teamID lgID W  L  G  GS CG ⋯ IBB WP HBP BK BFP  GF R
# 1 bechtge01 1871   1     PH1    NA    1  2  3  3  2 ⋯ NA   7 NA  0   146 0   42
# 2 brainas01 1871   1     WS3    NA   12 15 30 30 30 ⋯ NA   7 NA  0  1291 0  292
# 3 fergubo01 1871   1     NY2    NA    0  0  1  0  0 ⋯ NA   2 NA  0    14 0    9
# 4 fishech01 1871   1     RC1    NA    4 16 24 24 22 ⋯ NA  20 NA  0  1080 1  257
# 5 fleetfr01 1871   1     NY2    NA    0  1  1  1  1 ⋯ NA   0 NA  0    57 0   21
# 6 flowedi01 1871   1     TRO    NA    0  0  1  0  0 ⋯ NA   0 NA  0     3 1    0
#   SH SF GIDP
# 1 NA NA NA
# 2 NA NA NA
# 3 NA NA NA
# 4 NA NA NA
# 5 NA NA NA
# 6 NA NA NA

# %%
pitchers = as.data.table(Pitching)

# %%
pitchers = pitchers[, .(playerID,yearID,
                  lgID = as.character(lgID), 
                  teamID = as.character(teamID), 
                  G, W, L, ERA, BB, 
                  WinRatio = W/G)]

# %%
head(pitchers)
# Out:
#   playerID  yearID lgID teamID G  W  L  ERA   BB WinRatio
# 1 bechtge01 1871   NA   PH1     3  1  2  7.96 11 0.3333333
# 2 brainas01 1871   NA   WS3    30 12 15  4.50 37 0.4000000
# 3 fergubo01 1871   NA   NY2     1  0  0 27.00  0 0.0000000
# 4 fishech01 1871   NA   RC1    24  4 16  4.35 31 0.1666667
# 5 fleetfr01 1871   NA   NY2     1  0  1 10.00  3 0.0000000
# 6 flowedi01 1871   NA   TRO     1  0  0  0.00  0 0.0000000

# %%
pitchersP <- pitchers[yearID >= "2000"]

# %%
pitchersD <-pitchersP[G >="8"]

# %%
summary(pitchersD)
# Out:
#    playerID             yearID         lgID              teamID
#  Length:754         Min.   :2000   Length:754         Length:754
#  Class :character   1st Qu.:2005   Class :character   Class :character
#  Mode  :character   Median :2009   Mode  :character   Mode  :character
#                     Mean   :2009
#                     3rd Qu.:2014
#                     Max.   :2018
#        G               W               L               ERA
#  Min.   : 8.00   Min.   : 0.00   Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 8.00   1st Qu.: 0.00   1st Qu.: 0.000   1st Qu.: 3.600
#  Median : 9.00   Median : 1.00   Median : 1.000   Median : 5.285
#  Mean   :15.69   Mean   : 1.34   Mean   : 1.682   Mean   : 5.635
#  3rd Qu.: 9.00   3rd Qu.: 2.00   3rd Qu.: 3.000   3rd Qu.: 7.040
#  Max.   :94.00   Max.   :11.00   Max.   :12.000   Max.   :24.430
#        BB           WinRatio
#  Min.   : 0.00   Min.   :0.00000
#  1st Qu.: 5.00   1st Qu.:0.00000
#  Median : 9.00   Median :0.04908
#  Mean   :11.42   Mean   :0.10477
#  3rd Qu.:16.00   3rd Qu.:0.12500
#  Max.   :46.00   Max.   :0.62500

# %%
is.na(pitchersD)
# Out:
#       playerID yearID lgID  teamID G     W     L     ERA   BB    WinRatio
#  [1,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [2,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [3,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [4,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [5,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [6,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [7,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [8,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
#  [9,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [10,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [11,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [12,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [13,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [14,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [15,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [16,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [17,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [18,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [19,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [20,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [21,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [22,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [23,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [24,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [25,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [26,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [27,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [28,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [29,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [30,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [31,] ⋮        ⋮      ⋮     ⋮      ⋮     ⋮     ⋮     ⋮     ⋮     ⋮
# [32,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [33,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [34,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [35,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [36,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [37,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [38,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [39,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [40,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [41,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [42,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [43,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [44,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [45,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [46,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [47,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [48,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [49,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [50,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [51,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [52,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [53,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [54,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [55,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [56,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [57,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [58,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [59,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [60,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE
# [61,] FALSE    FALSE  FALSE FALSE  FALSE FALSE FALSE FALSE FALSE FALSE

# %%
head(pitchersD)
# Out:
#   playerID  yearID lgID teamID G W L ERA   BB WinRatio
# 1 andrecl01 2000   AL   TOR    8 1 2 10.02  9 0.1250000
# 2 belchti01 2000   AL   ANA    9 4 5  6.86 22 0.4444444
# 3 botteke01 2000   NL   PHI    8 1 2  4.50 21 0.1250000
# 4 cammaer01 2000   NL   NYN    8 0 0  6.30 10 0.0000000
# 5 carragi01 2000   NL   COL    8 0 1 12.83 11 0.0000000
# 6 carrahe01 2000   AL   BOS    8 1 1  9.45  5 0.1250000

# %%
show(pitchersD)
# Out:
#       playerID yearID lgID teamID G W L   ERA BB  WinRatio
#   1: andrecl01   2000   AL    TOR 8 1 2 10.02  9 0.1250000
#   2: belchti01   2000   AL    ANA 9 4 5  6.86 22 0.4444444
#   3: botteke01   2000   NL    PHI 8 1 2  4.50 21 0.1250000
#   4: cammaer01   2000   NL    NYN 8 0 0  6.30 10 0.0000000
#   5: carragi01   2000   NL    COL 8 0 1 12.83 11 0.0000000
#  ---
# 750: triggan01   2018   AL    OAK 9 3 1  5.23 18 0.3333333
# 751: valdefr01   2018   AL    HOU 8 4 1  2.19 24 0.5000000
# 752: vasquan02   2018   AL    MIN 9 1 0  5.40  2 0.1111111
# 753: wainwad01   2018   NL    SLN 8 2 4  4.46 18 0.2500000
# 754: waldema01   2018   AL    BOS 8 0 0  3.68  3 0.0000000

# %%
# Out:
# Classes ‘data.table’ and 'data.frame':	13778 obs. of  10 variables:
#  $ playerID: chr  "abbotpa01" "aceveju01" "adamste01" "aguilri01" ...
#  $ yearID  : int  2000 2000 2000 2000 2000 2000 2000 2000 2000 2000 ...
#  $ lgID    : chr  "AL" "NL" "NL" "NL" ...
#  $ teamID  : chr  "SEA" "MIL" "LAN" "CHN" ...
#  $ G       : int  35 62 66 54 23 68 67 62 11 33 ...
#  $ W       : int  9 3 6 1 1 5 4 4 0 11 ...
#  $ L       : int  7 7 9 2 3 6 2 5 0 7 ...
#  $ ERA     : num  4.22 3.81 3.52 4.91 5.75 4.24 4.86 4.39 13.5 4.05 ...
#  $ BB      : int  80 31 39 18 10 24 43 25 7 39 ...
#  $ WinRatio: num  0.2571 0.0484 0.0909 0.0185 0.0435 ...
#  - attr(*, ".internal.selfref")=<externalptr>

# %%
summary(pitchersD)
# Out:
#    playerID             yearID         lgID              teamID
#  Length:754         Min.   :2000   Length:754         Length:754
#  Class :character   1st Qu.:2005   Class :character   Class :character
#  Mode  :character   Median :2009   Mode  :character   Mode  :character
#                     Mean   :2009
#                     3rd Qu.:2014
#                     Max.   :2018
#        G               W               L               ERA
#  Min.   : 8.00   Min.   : 0.00   Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 8.00   1st Qu.: 0.00   1st Qu.: 0.000   1st Qu.: 3.600
#  Median : 9.00   Median : 1.00   Median : 1.000   Median : 5.285
#  Mean   :15.69   Mean   : 1.34   Mean   : 1.682   Mean   : 5.635
#  3rd Qu.: 9.00   3rd Qu.: 2.00   3rd Qu.: 3.000   3rd Qu.: 7.040
#  Max.   :94.00   Max.   :11.00   Max.   :12.000   Max.   :24.430
#        BB           WinRatio
#  Min.   : 0.00   Min.   :0.00000
#  1st Qu.: 5.00   1st Qu.:0.00000
#  Median : 9.00   Median :0.04908
#  Mean   :11.42   Mean   :0.10477
#  3rd Qu.:16.00   3rd Qu.:0.12500
#  Max.   :46.00   Max.   :0.62500

# %%
ggplot(pitchersD, aes(x = WinRatio, y = ERA,)) + geom_point()
# Out:
# plot without title

# %%
install.packages("tidyverse", repos = "https://cloud.r-project.org")
# Out:
# also installing the dependencies ‘ps’, ‘processx’, ‘callr’, ‘fs’, ‘reprex’
#
# Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘ps’ had non-zero exit status”Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘fs’ had non-zero exit status”Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘processx’ had non-zero exit status”Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘callr’ had non-zero exit status”Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘reprex’ had non-zero exit status”Warning message in install.packages("tidyverse", repos = "https://cloud.r-project.org"):
# “installation of package ‘tidyverse’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("cluster")    # clustering algorithms
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("factoextra", repos='http://cran.us.r-project.org') # clustering algorithms & visualization
# Out:
# Warning message:
# “dependency ‘fpc’ is not available”also installing the dependencies ‘zip’, ‘openxlsx’, ‘nloptr’, ‘pbkrtest’, ‘rio’, ‘lme4’, ‘car’, ‘dendextend’, ‘FactoMineR’
#
# Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘zip’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘nloptr’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘dendextend’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘openxlsx’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘lme4’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘pbkrtest’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘rio’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘car’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘FactoMineR’ had non-zero exit status”Warning message in install.packages("factoextra", repos = "http://cran.us.r-project.org"):
# “installation of package ‘factoextra’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library("tidyverse")  # data manipulation
# Out:
# Error in library("tidyverse"): there is no package called ‘tidyverse’
# Traceback:
#
# 1. library("tidyverse")
# 2. stop(txt, domain = NA)

# %%
library("cluster")

# %%
library("factoextra")
# Out:
# Error in library("factoextra"): there is no package called ‘factoextra’
# Traceback:
#
# 1. library("factoextra")
# 2. stop(txt, domain = NA)

# %%
distance <- get_dist(pitchersD)
fviz_dist(distance, gradient = list(low = "#00AFBB", mid = "white", high = "#FC4E07"))
# Out:
# Error in get_dist(pitchersD): could not find function "get_dist"
# Traceback:
